# %% [markdown]
# In this assignment we will use basic ideas of Set Theory to wrangle a clinical dataset using a
# programming language of your choice. Submit your code and datasets using your GitHub repository.
# Here is a quick refresher to Set Theory: htps://www.geeksforgeeks.org/set-theory/. These concepts are
# used to define inclusion and exclusion criteria of cohorts and in creaton of their corresponding datasets
# (htps://pubmed.ncbi.nlm.nih.gov/24026307/).
#
#
# COVID-19 has been associated with the occurrence new diabetes and hyperglycemia
# (htps://academic.oup.com/jamiaopen/artcle/4/3/ooab063/6320067). In this exercise you will use a
# synthetc diagnosis file containing patent IDs, ICD 10 diagnosis codes, and a date of diagnosis. You will
# need to use the following code sets for your wrangling steps:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

data = pd.read_csv("DW3_set_exercise.csv")
data.head()
# Out:
#    Unnamed: 0  Patient ID Diagnosis Code        Date
# 0           0   4725559.0          E03.9  2020-09-20
# 1           1   7637008.0          R53.1  2019-10-27
# 2           2   5068050.0          I48.1  2020-11-22
# 3           3   1342235.0          E11.9  2022-01-27
# 4           4   4520230.0          N39.0  2020-05-17

# %% [markdown]
# 1. Diabetes Set: (20 Points)
#     - Find all patents with Diabetes using the codes above by listng their patent IDs.
#     - Find the cardinality of the Diabetes set.

# %%
diabetes = data[data['Diagnosis Code'].str.contains('E08|E09|E10|E11|E13')]
diabetes_id = set(diabetes['Patient ID'].tolist())

print("Diabetes Patient IDs:")
print(diabetes_id)
print()

print("Diabetes Set Cardinality: " + str(len(diabetes_id)))
# Out:
# Diabetes Patient IDs:
# ...

# %% [markdown]
# 2. COVID Set: (20 Points)
#     - Find all patents with COVID using the codes above by listng their patent IDs.
#     - Find the cardinality of the COVID set.

# %%
covid = data[data['Diagnosis Code'].str.contains('U07.1|J12.82')]
covid_id = set(covid['Patient ID'].tolist())

print("COVID Patient IDs:")
print(covid_id)
print()

print("COVID Set Cardinality: " + str(len(covid_id)))
# Out:
# COVID Patient IDs:
# ...

# %% [markdown]
# 3. Intersecton Set (20 Points)
#     - Find all patents with Diabetes and COVID using the codes above by listng their patent
#     IDs.
#     - Find the cardinality of the Intersecton set.

# %%
intersection = pd.merge(diabetes, covid, on = "Patient ID")
intersection_id = set(intersection['Patient ID'].tolist())

print("Diabetes and COVID Intersection: ")
print(intersection_id)
print()

print("Intersection Set Cardinality: " + str(len(intersection_id)))
# Out:
# Diabetes and COVID Intersection:
# ...

# %% [markdown]
# 4. Union Set (20 Points)
#     - Find all patents with Diabetes or COVID using the codes above by listng their patent
#     IDs.
#     - Find the cardinality of the Intersecton set.

# %%
union = data[data['Diagnosis Code'].str.contains('E08|E09|E10|E11|E13|U07.1|J12.82')]
union_id = set(union['Patient ID'].tolist())

print("Diabetes and COVID Union: ")
print(union_id)
print()

print("Union Set Cardinality: " + str(len(union_id)))
# Out:
# Diabetes and COVID Union:
# ...

# %% [markdown]
# 5. Draw a Venn diagram showing the Diabetes, COVID, Intersec�on and Union sets You might need to use a package. (40 points)

# %%
# Create venn diagram
venn = venn2([diabetes_id, covid_id], ('Diabetes', 'COVID'))
# Label intersection
venn.get_label_by_id('11').set_text('Intersection\n{}'.format(len(diabetes_id & covid_id)))
# Create union label
plt.text(0.3, -0.5, 'Union\n{}'.format(len(diabetes_id | covid_id)), ha='center')
plt.title("Diabetes and COVID Venn Diagram")
plt.show()

# %% [markdown]
# 6. Diabetes only ater COVID Set (30 points)
#   - Now including the date of diagnosis, find all patents with Diabetes only ater they had
#   COVID by listng their patent IDs.
#   - Find the cardinality of the Diabetes only ater COVID set.
#   - Provide a count breakdown for each of the diabetes codes listed above occurring only
#   ater COVID.

# %%
diabetes_after_covid = []
for index, row in intersection.iterrows():
    if row['Date_y'] > row['Date_x']:
        diabetes_after_covid.append(row)

# Convert to df
dac_df = pd.DataFrame(diabetes_after_covid)
dac_id = set(dac_df['Patient ID'].tolist())

diabetes_count = dac_df["Diagnosis Code_x"].value_counts()

print("Diabetes after COVID Patient IDs: ")
print(dac_id)
print()

print("Diabetes after COVID Set Cardinality: " +str(len(dac_id)))
print()

print("Diabetes Code Breakdown:")
print(diabetes_count)
# Out:
# Diabetes after COVID Patient IDs:
# ...
